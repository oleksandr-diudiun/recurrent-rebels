# %%
from sklearn import datasets

# load iris dataset
iris = datasets.load_iris()

# %%
import pandas as pd

# since this is a bunch, create a dataframe
iris_df=pd.DataFrame(iris.data)
iris_df['class']=iris.target
iris_df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']
iris_df.dropna(how="all", inplace=True) # remove any empty lines

#view the iris dataframe
print(iris_df['class'][51])
# Out:
# 1

# %%
import numpy as np

# Define our neural network class
class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        # Hidden layer initialization
        self.W1 = np.random.rand(input_size, hidden_size)
        self.b1 = np.zeros((1, hidden_size))

        # Output layer initialization
        self.W2 = np.random.rand(hidden_size, output_size)
        self.b2 = np.zeros((1, output_size))

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def relu(self, x):
        return np.maximum(0, x)

    def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    # Subtract the max value from each score to prevent overflow in exp
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e_x / e_x.sum(axis=-1, keepdims=True)

    def forward(self, x):
        # calculate the activations in the hidden layer
        self.Z1 = np.dot(x, self.W1) + self.b1
        self.A1 = self.relu(self.Z1)

        # calculate activations for the output layer
        self.Z2 = np.dot(self.A1, self.W2) + self.b2
        y_hat = self.relu(self.Z2)
        return y_hat

# %%
# create a new instance of a neural network
nn = NeuralNetwork(input_size = 4, hidden_size = 8, output_size = 3)

X = iris_df[['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid']].values
#print(X)

y_hat = nn.forward(X)

print(y_hat)

Y = iris_df['class'].values.reshape(-1, 1)  # Reshape for consistency
#print(Y)
# Out:
# [[19.3902362  20.073657   17.91601119]
#  [17.90357178 18.59184297 16.4766528 ]
#  [17.86664465 18.49936866 16.50193153]
#  [17.77219817 18.37031056 16.47295529]
#  [19.44814664 20.09835316 18.0137462 ]
#  [21.79475415 22.49143936 20.20099234]
#  [18.56498954 19.15220751 17.2197967 ]
#  [19.14304171 19.80273227 17.71684366]
#  [16.81956515 17.40286119 15.56404636]
#  [18.02648629 18.68492107 16.66399905]
#  [20.51388525 21.23515397 18.96073203]
#  [18.95375766 19.55650369 17.61541114]
#  [17.47379578 18.13026307 16.12444894]
#  [16.16047158 16.73442515 14.93481555]
#  [21.42648474 22.24197579 19.69404653]
#  [23.14693858 23.88356773 21.43578006]
#  [21.1837621  21.92397283 19.52022719]
#  [19.64899617 20.3411893  18.13240314]
#  [21.82011581 22.58730611 20.15848919]
#  [20.48852359 21.13928722 19.00323518]
#  [20.13260186 20.86265595 18.60047386]
#  [20.51835709 21.18807576 18.98608022]
#  [18.15309046 18.75469622 16.78973342]
#  [20.1669072  20.86436626 18.60866708]
#  [19.4120017  19.98210359 18.125985  ]
